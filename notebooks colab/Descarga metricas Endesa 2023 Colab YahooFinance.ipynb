# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# Descargo  datos de Endesa
ticker = yf.Ticker("ELE.MC")
# Aqui procedo con el historial del ticker asociado con las fechas del año entero 2023
df_bolsa = ticker.history(start="2023-01-01", end="2023-12-31")
df_bolsa.reset_index(inplace=True)
# Y saco por pantalla un head de las métricas más importantes.
print(df_bolsa.head())
# Out:
#                        Date       Open       High        Low      Close  \
# 0 2023-01-02 00:00:00+01:00  14.530436  14.718717  14.444481  14.669600
# 1 2023-01-03 00:00:00+01:00  14.653227  14.894719  14.546808  14.739182
# 2 2023-01-04 00:00:00+01:00  14.816954  15.349055  14.816954  15.295844
# 3 2023-01-05 00:00:00+01:00  15.218075  15.349054  15.062538  15.123935
# 4 2023-01-06 00:00:00+01:00  15.156676  15.398168  15.062535  15.394075
#
#     Volume  Dividends  Stock Splits
# 0   528063        0.0           0.0
# 1  1185399        0.0           0.0
# 2  2089191        0.0           0.0
# 3  1641596        0.0           0.0
# 4   821399        0.0           0.0
